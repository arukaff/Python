# %% [markdown]
# Урок 10. Работа с признаками
# Вам предстоит провести эксперименты с моделью машинного обучения и изучить процесс кросс-валидации и подбора гиперпараметров.
#
# Ваша задача состоит в следующем:
#
# 1. Загрузите набор данных, подходящий для задачи классификации или регрессии. Вы можете использовать любой набор данных, предоставленный в библиотеке scikit-learn или другом доступном источнике данных.
#
# 2. Разделите данные на обучающую и тестовую выборки с помощью функции train_test_split из библиотеки scikit-learn.
#
# 3. Создайте модель машинного обучения, которую вы хотите использовать для предсказания на этом наборе данных. Например, можно использовать модель линейной регрессии или случайный лес для задачи регрессии, или модель логистической регрессии или случайный лес для задачи классификации.
#
# 4. Используйте метод кросс-валидации, чтобы оценить производительность модели на обучающей выборке. Например, можно использовать метод cross_val_score из библиотеки scikit-learn с использованием метрики оценки, такой как точность (accuracy) или среднеквадратичная ошибка (mean squared error).
#
# 5. Проведите подбор гиперпараметров модели с помощью метода GridSearchCV из библиотеки scikit-learn. Этот метод позволяет перебирать различные значения гиперпараметров и выбирать наилучшие значения на основе кросс-валидации.
#
# 6. Обучите модель с использованием оптимальных гиперпараметров на обучающей выборке и оцени ее производительность на тестовой выборке.
#
# 7. Проведите анализ результатов и сделай выводы о процессе кросс-валидации и подборе гиперпараметров в задачах машинного обучения.

# %% [markdown]
# *Возьмем за основу датасет телекомов из предыдущего семинара - решаем задачу предсказания переходов клиентов к другому оператору*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.options.mode.copy_on_write = True

df = pd.read_csv("telecom_churn.csv")
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False

# %% [markdown]
# *Проводим первичную обработку данных*

# %%
df = df.drop('State', axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l = LabelEncoder()
df['International plan'] = l.fit_transform(df['International plan'])
df['Voice mail plan'] = l.fit_transform(df['Voice mail plan'])
df['Churn'] = l.fit_transform(df['Churn'])

# %%
df.head()
# Out:
#    Account length  Area code  International plan  Voice mail plan  \
# 0             128        415                   0                1
# 1             107        415                   0                1
# 2             137        415                   0                0
# 3              84        408                   1                0
# 4              75        415                   1                0
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                       1      0
# 1                       1      0
# 2                       0      0
# 3                       2      0
# 4                       3      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Account length          3333 non-null   int64
#  1   Area code               3333 non-null   int64
#  2   International plan      3333 non-null   int32
#  3   Voice mail plan         3333 non-null   int32
#  4   Number vmail messages   3333 non-null   int64
#  5   Total day minutes       3333 non-null   float64
#  6   Total day calls         3333 non-null   int64
#  7   Total day charge        3333 non-null   float64
#  8   Total eve minutes       3333 non-null   float64
#  9   Total eve calls         3333 non-null   int64
#  10  Total eve charge        3333 non-null   float64
#  11  Total night minutes     3333 non-null   float64
#  12  Total night calls       3333 non-null   int64
#  13  Total night charge      3333 non-null   float64
#  14  Total intl minutes      3333 non-null   float64
#  15  Total intl calls        3333 non-null   int64
#  16  Total intl charge       3333 non-null   float64
#  17  Customer service calls  3333 non-null   int64
#  18  Churn                   3333 non-null   int64
# dtypes: float64(8), int32(2), int64(9)
# memory usage: 468.8 KB

# %% [markdown]
# *В датасете остались только числовые значения*

# %%
pip install Jinja2
# Out:
# Collecting Jinja2
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rukavishnikovav\python\.venv\lib\site-packages (from Jinja2) (3.0.2)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Installing collected packages: Jinja2
# Successfully installed Jinja2-3.1.6
# Note: you may need to restart the kernel to use updated packages.

# %%
df.describe().T.style.background_gradient(cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_e8731_row0_col0, #T_e8731_row0_col3, #T_e8731_row1_col0, #T_e8731_row2_col0, #T_e8731_row2_col1, #T_e8731_row2_col2, #T_e8731_row2_col3, #T_e8731_row2_col4, #T_e8731_row2_col5, #T_e8731_row2_col6, #T_e8731_row2_col7, #T_e8731_row3_col0, #T_e8731_row3_col1, #T_e8731_row3_col2, #T_e8731_row3_col3, #T_e8731_row3_col4, #T_e8731_row3_col5, #T_e8731_row3_col6, #T_e8731_row3_col7, #T_e8731_row4_col0, #T_e8731_row4_col3, #T_e8731_row4_col4, #T_e8731_row4_col5, #T_e8731_row5_col0, #T_e8731_row5_col3, #T_e8731_row6_col0, #T_e8731_row6_col3, #T_e8731_row7_col0, #T_e8731_row7_col3, #T_e8731_row8_col0, #T_e8731_row8_col3, #T_e8731_row9_col0, #T_e8731_row9_col3, #T_e8731_row10_col0, #T_e8731_row10_col3, #T_e8731_row11_col0, #T_e8731_row12_col0, #T_e8731_row13_col0, #T_e8731_row13_col3, #T_e8731_row14_col0, #T_e8731_row14_col3, #T_e8731_row15_col0, #T_e8731_row15_col3, #T_e8731_row16_col0, #T_e8731_row16_col3, #T_e8731_row17_col0, #T_e8731_row17_col1, #T_e8731_row17_col3, #T_e8731_row17_col4, #T_e8731_row17_col5, #T_e8731_row18_col0, #T_e8731_row18_col1, #T_e8731_row18_col2, #T_e8731_row18_col3, #T_e8731_row18_col4, #T_e8731_row18_col5, #T_e8731_row18_col6, #T_e8731_row18_col7 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_e8731_row0_col1 {
#   background-color: #fedc7c;
#   color: #000000;
# }
# #T_e8731_row0_col2 {
#   background-color: #e7231e;
#   color: #f1f1f1;
# }
# #T_e8731_row0_col4 {
#   background-color: #ffe48d;
#   color: #000000;
# }
# #T_e8731_row0_col5, #T_e8731_row6_col5 {
#   background-color: #feda78;
#   color: #000000;
# }
# #T_e8731_row0_col6, #T_e8731_row4_col2 {
#   background-color: #fed977;
#   color: #000000;
# }
# #T_e8731_row0_col7 {
#   background-color: #fd953f;
#   color: #000000;
# }
# #T_e8731_row1_col1, #T_e8731_row1_col3, #T_e8731_row1_col4, #T_e8731_row1_col5, #T_e8731_row1_col6, #T_e8731_row1_col7, #T_e8731_row5_col2 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_e8731_row1_col2, #T_e8731_row11_col7 {
#   background-color: #db141e;
#   color: #f1f1f1;
# }
# #T_e8731_row4_col1, #T_e8731_row13_col4, #T_e8731_row17_col2, #T_e8731_row17_col7 {
#   background-color: #fffdc6;
#   color: #000000;
# }
# #T_e8731_row4_col6, #T_e8731_row10_col5, #T_e8731_row10_col6, #T_e8731_row15_col2 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_e8731_row4_col7 {
#   background-color: #fff1a9;
#   color: #000000;
# }
# #T_e8731_row5_col1 {
#   background-color: #fea747;
#   color: #000000;
# }
# #T_e8731_row5_col4 {
#   background-color: #feb953;
#   color: #000000;
# }
# #T_e8731_row5_col5 {
#   background-color: #fea145;
#   color: #000000;
# }
# #T_e8731_row5_col6 {
#   background-color: #fea446;
#   color: #000000;
# }
# #T_e8731_row5_col7 {
#   background-color: #f03523;
#   color: #f1f1f1;
# }
# #T_e8731_row6_col1, #T_e8731_row9_col1, #T_e8731_row12_col1 {
#   background-color: #fedd7e;
#   color: #000000;
# }
# #T_e8731_row6_col2 {
#   background-color: #feb54f;
#   color: #000000;
# }
# #T_e8731_row6_col4, #T_e8731_row9_col4, #T_e8731_row12_col4 {
#   background-color: #fedf83;
#   color: #000000;
# }
# #T_e8731_row6_col6, #T_e8731_row9_col6 {
#   background-color: #fedd7f;
#   color: #000000;
# }
# #T_e8731_row6_col7 {
#   background-color: #fec35e;
#   color: #000000;
# }
# #T_e8731_row7_col1 {
#   background-color: #fff5b5;
#   color: #000000;
# }
# #T_e8731_row7_col2 {
#   background-color: #ffe793;
#   color: #000000;
# }
# #T_e8731_row7_col4, #T_e8731_row10_col7 {
#   background-color: #fff7b7;
#   color: #000000;
# }
# #T_e8731_row7_col5, #T_e8731_row7_col6, #T_e8731_row10_col2 {
#   background-color: #fff5b3;
#   color: #000000;
# }
# #T_e8731_row7_col7 {
#   background-color: #ffefa4;
#   color: #000000;
# }
# #T_e8731_row8_col1, #T_e8731_row11_col1 {
#   background-color: #fd9941;
#   color: #000000;
# }
# #T_e8731_row8_col2 {
#   background-color: #a10026;
#   color: #f1f1f1;
# }
# #T_e8731_row8_col4, #T_e8731_row11_col4 {
#   background-color: #fea848;
#   color: #000000;
# }
# #T_e8731_row8_col5, #T_e8731_row11_col5 {
#   background-color: #fd913e;
#   color: #000000;
# }
# #T_e8731_row8_col6, #T_e8731_row11_col6 {
#   background-color: #fd9841;
#   color: #000000;
# }
# #T_e8731_row8_col7 {
#   background-color: #ea2920;
#   color: #f1f1f1;
# }
# #T_e8731_row9_col2 {
#   background-color: #feb651;
#   color: #000000;
# }
# #T_e8731_row9_col5, #T_e8731_row12_col5 {
#   background-color: #fedb7a;
#   color: #000000;
# }
# #T_e8731_row9_col7 {
#   background-color: #fec05b;
#   color: #000000;
# }
# #T_e8731_row10_col1, #T_e8731_row13_col2, #T_e8731_row14_col7, #T_e8731_row15_col7 {
#   background-color: #fffac0;
#   color: #000000;
# }
# #T_e8731_row10_col4, #T_e8731_row13_col7 {
#   background-color: #fffac1;
#   color: #000000;
# }
# #T_e8731_row11_col2 {
#   background-color: #a20026;
#   color: #f1f1f1;
# }
# #T_e8731_row11_col3 {
#   background-color: #fff7b9;
#   color: #000000;
# }
# #T_e8731_row12_col2 {
#   background-color: #feb852;
#   color: #000000;
# }
# #T_e8731_row12_col3 {
#   background-color: #fff4b0;
#   color: #000000;
# }
# #T_e8731_row12_col6 {
#   background-color: #fede80;
#   color: #000000;
# }
# #T_e8731_row12_col7 {
#   background-color: #febd57;
#   color: #000000;
# }
# #T_e8731_row13_col1, #T_e8731_row13_col5, #T_e8731_row13_col6, #T_e8731_row14_col1, #T_e8731_row14_col4 {
#   background-color: #fffcc5;
#   color: #000000;
# }
# #T_e8731_row14_col2 {
#   background-color: #fff9bd;
#   color: #000000;
# }
# #T_e8731_row14_col5, #T_e8731_row14_col6 {
#   background-color: #fffcc4;
#   color: #000000;
# }
# #T_e8731_row15_col1, #T_e8731_row15_col5, #T_e8731_row16_col2, #T_e8731_row16_col7 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_e8731_row15_col4, #T_e8731_row16_col1, #T_e8731_row16_col4, #T_e8731_row16_col5, #T_e8731_row16_col6, #T_e8731_row17_col6 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_e8731_row15_col6 {
#   background-color: #fffdc8;
#   color: #000000;
# }
# </style>
# <table id="T_e8731">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8731_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_e8731_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_e8731_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_e8731_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_e8731_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_e8731_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_e8731_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_e8731_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8731_level0_row0" class="row_heading level0 row0" >Account length</th>
#       <td id="T_e8731_row0_col0" class="data row0 col0" >3333.000000</td>
#       <td id="T_e8731_row0_col1" class="data row0 col1" >101.064806</td>
#       <td id="T_e8731_row0_col2" class="data row0 col2" >39.822106</td>
#       <td id="T_e8731_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_e8731_row0_col4" class="data row0 col4" >74.000000</td>
#       <td id="T_e8731_row0_col5" class="data row0 col5" >101.000000</td>
#       <td id="T_e8731_row0_col6" class="data row0 col6" >127.000000</td>
#       <td id="T_e8731_row0_col7" class="data row0 col7" >243.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e8731_level0_row1" class="row_heading level0 row1" >Area code</th>
#       <td id="T_e8731_row1_col0" class="data row1 col0" >3333.000000</td>
#       <td id="T_e8731_row1_col1" class="data row1 col1" >437.182418</td>
#       <td id="T_e8731_row1_col2" class="data row1 col2" >42.371290</td>
#       <td id="T_e8731_row1_col3" class="data row1 col3" >408.000000</td>
#       <td id="T_e8731_row1_col4" class="data row1 col4" >408.000000</td>
#       <td id="T_e8731_row1_col5" class="data row1 col5" >415.000000</td>
#       <td id="T_e8731_row1_col6" class="data row1 col6" >510.000000</td>
#       <td id="T_e8731_row1_col7" class="data row1 col7" >510.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e8731_level0_row2" class="row_heading level0 row2" >International plan</th>
#       <td id="T_e8731_row2_col0" class="data row2 col0" >3333.000000</td>
#       <td id="T_e8731_row2_col1" class="data row2 col1" >0.096910</td>

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# *Дубликатов, пропущенных значений - нет*

# %% [markdown]
# *Создаем матрицу объект-признак X и вектор с целевой переменной (Churn) y.*

# %%
X = df.drop("Churn", axis=1)
y = df["Churn"]

# %% [markdown]
# *Проверяем баланс классов*

# %%
df['Churn'].value_counts(sort = False)
# Out:
# Churn
# 0    2850
# 1     483
# Name: count, dtype: int64

# %% [markdown]
# *По целевому показателю выборка не сбалансированная - данных с меньшим классом (положительное значение Churn) в 5,9 раз меньше, чем с отрицательным значением Churn*

# %%
df['Churn'].value_counts().plot(kind='bar');
plt.title('Гистограмма распределения целевой переменной (Churn)')
# Out:
# Text(0.5, 1.0, 'Гистограмма распределения целевой переменной (Churn)')

# %% [markdown]
# *Разбиваем данные на тренировочную и тестовую части, размер тестовой части — 30%, стратифицированное разбиение в связи с дисбалансом классов*

# %%
from sklearn.model_selection import train_test_split, cross_val_score

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
X_train
# Out:
#       Account length  Area code  International plan  Voice mail plan  \
# 606              129        415                   0                0
# 2468             152        510                   1                1
# 1844              77        510                   0                1
# 3187              58        408                   0                1
# 3083             174        510                   0                0
# ...              ...        ...                 ...              ...
# 2670             116        510                   0                1
# 2165             160        415                   0                0
# 2988             105        415                   0                0
# 179               70        408                   0                0
# 2762              80        408                   0                0
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 606                       0              139.5              119
# 2468                     41              146.8              128
# 1844                     28              135.9              117
# 3187                     39              211.9               40
# 3083                      0              235.5              108
# ...                     ...                ...              ...
# 2670                     12              221.0              108
# 2165                      0              171.2              103
# 2988                      0              259.3               96
# 179                       0              232.1              122
# 2762                      0               51.5               90
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 606              23.72              289.3              105             24.59
# 2468             24.96              285.6               96             24.28
# 1844             23.10              244.5              102             20.78
# 3187             36.02              274.4               76             23.32
# 3083             40.04              142.3              143             12.10
# ...                ...                ...              ...               ...
# 2670             37.57              151.0              118             12.84
# 2165             29.10              243.5              121             20.70
# 2988             44.08              175.2               97             14.89
# 179              39.46              292.3              112             24.85
# 2762              8.76              164.0               98             13.94
#
#       Total night minutes  Total night calls  Total night charge  \
# 606                 129.4                 97                5.82
# 2468                213.6                 80                9.61
# 1844                207.5                 74                9.34
# 3187                210.5                139                9.47
# 3083                316.7                131               14.25
# ...                   ...                ...                 ...
# 2670                179.0                 80                8.06
# 2165                178.2                 92                8.02
# 2988                222.4                 36               10.01
# 179                 201.2                112                9.05
# 2762                169.4                 80                7.62
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 606                 13.1                 8               3.54
# 2468                 4.3                 2               1.16
# 1844                11.5                 3               3.11
# 3187                 5.4                 4               1.46
# 3083                12.5                 5               3.38
# ...                  ...               ...                ...
# 2670                 9.0                 6               2.43
# 2165                13.0                 3               3.51
# 2988                12.0                 5               3.24
# 179                  0.0                 0               0.00
# 2762                 9.5                 4               2.57
#
#       Customer service calls
# 606                        0
# 2468                       1
# 1844                       4
# 3187                       1
# 3083                       0
# ...                      ...
# 2670                       2
# 2165                       2
# 2988                       3
# 179                        3
# 2762                       3
#
# [2333 rows x 18 columns]

# %% [markdown]
# *Масштабируем признаки*

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
#X_train = pd.DataFrame(X_train, columns=X_train0.columns)
#X_test = pd.DataFrame(X_test, columns=X_test0.columns)

# %%
X_train
# Out:
# array([[ 0.71072961, -0.5107321 , -0.31860769, ...,  1.44537268,
#          1.01225356, -1.20282632],
#        [ 1.28536821,  1.75659106,  3.13865621, ..., -1.03104431,
#         -2.08997043, -0.43295148],
#        [-0.58845332,  1.75659106, -0.31860769, ..., -0.61830814,
#          0.45176772,  1.87667306],
#        ...,
#        [ 0.11110672, -0.5107321 , -0.31860769, ...,  0.20716419,
#          0.62121693,  1.10679821],
#        [-0.76334332, -0.67779801, -0.31860769, ..., -1.85651664,
#         -3.60197876,  1.10679821],
#        [-0.51350045, -0.67779801, -0.31860769, ..., -0.20557198,
#         -0.25209823,  1.10679821]])

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, auc, confusion_matrix
from sklearn import metrics
import seaborn as sns

# %% [markdown]
# -------------------------------------------

# %% [markdown]
# **Бэггинг (RandomForestClessifier)**

# %% [markdown]
# *Строим BaseLine модель классификаци - RandomForestClassifier, с параметрами "из коробки"*

# %%
from sklearn.ensemble import RandomForestClassifier

model1 = RandomForestClassifier()
model1.fit(X_train, y_train)
y_pred1 = model1.predict(X_test)
print(classification_report(y_test, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       855
#            1       0.94      0.72      0.82       145
#
#     accuracy                           0.95      1000
#    macro avg       0.95      0.86      0.90      1000
# weighted avg       0.95      0.95      0.95      1000

# %% [markdown]
# *Имеем неплохие показатели - Recall 71% на минорном классе (какую долю реальных переходов к другому оператору удалось верно предсказать модели), показатель Precision (сколько из предсказанных переходов на тестовой выборке в реальности были переходами) 92%*

# %%
confusion_mat = confusion_matrix(y_test, y_pred1)
print("Точность:", accuracy_score(y_test, y_pred1))
print("Точность:", precision_score(y_test, y_pred1, average = 'binary'))
print("Полнота:", recall_score(y_test, y_pred1, average = 'binary'))
print("F1-мера:", f1_score(y_test, y_pred1, average = 'binary'))
# Out:
# Точность: 0.953
# Точность: 0.9375
# Полнота: 0.7241379310344828
# F1-мера: 0.8171206225680934

# %%
sns.heatmap(confusion_mat, annot=True, fmt="d", cmap = "Blues")
plt.xlabel("Прогноз")
plt.ylabel("Фактическое значение")
plt.title("Матрица ошибок")
plt.show();

# %%
#Предсказываем вероятности
y_pred_proba1 = model1.predict_proba(X_test)[:, 1]
# Строим кривую ROC
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred_proba1)
plt.plot(fpr, tpr)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
auc = metrics.roc_auc_score(y_test, y_pred_proba1)
print("AUC: %.3f" % auc)
# Out:
# AUC: 0.903

# %%
import plotly.graph_objs as go

trace = go.Scatter(x=fpr, y=tpr, mode='lines', name='AUC = %0.2f' % auc,
                   line=dict(color='darkorange', width=2))
reference_line = go.Scatter(x=[0,1], y=[0,1], mode='lines', name='Reference Line',
                            line=dict(color='navy', width=2, dash='dash'))
fig = go.Figure(data=[trace, reference_line])
fig.update_layout(title='Interactive ROC Curve',
                  xaxis_title='False Positive Rate',
                  yaxis_title='True Positive Rate')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 11
#       7 fig = go.Figure(data=[trace, reference_line])
#       8 fig.update_layout(title='Interactive ROC Curve',
#       9                   xaxis_title='False Positive Rate',
#      10                   yaxis_title='True Positive Rate')
# ---> 11 fig.show()
#
# File c:\Users\rukavishnikovav\Python\.venv\Lib\site-packages\plotly\basedatatypes.py:3414, in BaseFigure.show(self, *args, **kwargs)
#    3381 """
#    3382 Show a figure using either the default renderer(s) or the renderer(s)
#    3383 specified by the renderer argument
#    (...)
#    3410 None
#    3411 """
#    3412 import plotly.io as pio
# -> 3414 return pio.show(self, *args, **kwargs)
#
# File c:\Users\rukavishnikovav\Python\.venv\Lib\site-packages\plotly\io\_renderers.py:425, in show(fig, renderer, validate, **kwargs)
#     420     raise ValueError(
#     421         "Mime type rendering requires ipython but it is not installed"
#     422     )
#     424 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 425     raise ValueError(
#     426         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     427     )
#     429 display_jupyter_version_warnings()
#     431 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %% [markdown]
# *Показатель AUC (Area under Curve) - площади под кривой ROC - интерпретирует вероятность, с которой модель верно определит две точки (объекта), расположенные в разных классах, которые поданы ей на вход для анализа. В нашем случае это вероятность 90,5%. Показатель 50% (площадь под синей пунктирной кривой - вариант случайного выбора, рандомного угадывания).*

# %% [markdown]
# *Визуализируем важность признаков для предсказания целевого признака Churn:*

# %%
feats = {}
for feature, importance in zip(df.columns, model1.feature_importances_):
    feats[feature] = importance
importances = pd.DataFrame.from_dict(feats, orient='index').rename(columns={0: 'Gini-Importance'})
importances = importances.sort_values(by='Gini-Importance', ascending=False)
importances = importances.reset_index()
importances = importances.rename(columns={'index': 'Features'})
sns.set(font_scale = 5)
sns.set(style="whitegrid", color_codes=True, font_scale = 1.7)
fig, ax = plt.subplots()
fig.set_size_inches(30,15)
sns.barplot(x=importances['Gini-Importance'], y=importances['Features'], data=importances, color='skyblue')
plt.xlabel('Importance', fontsize=25, weight = 'bold')
plt.ylabel('Features', fontsize=25, weight = 'bold')
plt.title('Feature Importance', fontsize=25, weight = 'bold')
display(plt.show())
display(importances)
# Out:
# None
#                   Features  Gini-Importance
# 0        Total day minutes         0.153481
# 1   Customer service calls         0.125246
# 2         Total day charge         0.118707
# 3       International plan         0.074009
# 4         Total eve charge         0.068607
# 5        Total eve minutes         0.059453
# 6         Total intl calls         0.049296
# 7       Total intl minutes         0.046293
# 8        Total intl charge         0.039669
# 9       Total night charge         0.035607
# 10   Number vmail messages         0.035603
# 11         Total day calls         0.034952
# 12     Total night minutes         0.034235
# 13          Account length         0.031519
# 14       Total night calls         0.030399
# 15         Total eve calls         0.029777
# 16         Voice mail plan         0.024025
# 17               Area code         0.009122

# %% [markdown]
# *Часть признаков не оказывают существенного влияния на целевой параметр*

# %% [markdown]
# *Строим матрицу корреляций*

# %%
correlation_matrix = df.corr()
plt.figure(figsize= (40, 26))
sns.heatmap(correlation_matrix, annot = True)
# Out:
# <Axes: >

# %% [markdown]
# *Видим, что некоторые признаки абсолютно коррелируют друг с другом*

# %% [markdown]
# ---------------------------------

# %% [markdown]
# *Нами была использована модель RandomForestClassifier с гиперпараметрами "по умолчанию". Применим алгоритм GridSearchCV для нахождения оптимальных гиперпараметров в построении нашей модели. В качестве критерия выберем максимизацию показателя AUC (ROC)*

# %%
from sklearn.model_selection import GridSearchCV
# Функция для оценки модели с помощью перекрестной проверки
def evaluate_model(model1, X_train, y_train):
    scores = cross_val_score(model1, X_train, y_train, scoring='roc_auc', cv=5)
    return scores.mean()

# Поиск гиперпараметров с помощью сетки параметров
param_grid = {
    'n_estimators': [100, 300],
    'max_depth': [3, 9, 11],
    'min_samples_split': [2, 7, 10],
    'min_samples_leaf': [2, 5]
}

grid_search = GridSearchCV(estimator=model1, param_grid=param_grid, scoring='roc_auc', cv=5, n_jobs=-1)
grid_search.fit(X_train, y_train)

print(f"Лучшие гиперпараметры для модели (Grid Search): {grid_search.best_params_}")
print(f"Лучшая оценка для модели (Grid Search): {grid_search.best_score_:.2f}")
# Out:
# Лучшие гиперпараметры для модели (Grid Search): {'max_depth': 9, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100}
# Лучшая оценка для модели (Grid Search): 0.93

# %% [markdown]
# *Применим найденные гиперпараметры в построении модели, применим сбалансированные по классам веса*

# %%
model2 = RandomForestClassifier(n_estimators = 100, max_depth= 11, min_samples_split=7, min_samples_leaf=2)
model2.fit(X_train, y_train)
y_pred2 = model2.predict(X_test)
print(classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       855
#            1       0.94      0.72      0.81       145
#
#     accuracy                           0.95      1000
#    macro avg       0.95      0.85      0.89      1000
# weighted avg       0.95      0.95      0.95      1000

# %% [markdown]
# *Поиск гиперпараметров с помощью GridSearchCV не привел к существенному улучшению метрик качества модели*

# %%
confusion_mat = confusion_matrix(y_test, y_pred2)
print("Точность:", accuracy_score(y_test, y_pred2))
print("Точность:", precision_score(y_test, y_pred2, average = 'binary'))
print("Полнота:", recall_score(y_test, y_pred2, average = 'binary'))
print("F1-мера:", f1_score(y_test, y_pred2, average = 'binary'))
# Out:
# Точность: 0.952
# Точность: 0.9369369369369369
# Полнота: 0.7172413793103448
# F1-мера: 0.8125

# %%
sns.heatmap(confusion_mat, annot=True, fmt="d", cmap = "Blues")
plt.xlabel("Прогноз")
plt.ylabel("Фактическое значение")
plt.title("Матрица ошибок")
plt.show();

# %%
#Предсказываем вероятности
y_pred_proba2 = model2.predict_proba(X_test)[:, 1]
# Строим кривую ROC
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred_proba2)
plt.plot(fpr, tpr)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
auc = metrics.roc_auc_score(y_test, y_pred_proba2)
print("AUC: %.3f" % auc)
# Out:
# AUC: 0.907

# %%
trace = go.Scatter(x=fpr, y=tpr, mode='lines', name='AUC = %0.2f' % auc,
                   line=dict(color='darkorange', width=2))
reference_line = go.Scatter(x=[0,1], y=[0,1], mode='lines', name='Reference Line',
                            line=dict(color='navy', width=2, dash='dash'))
fig = go.Figure(data=[trace, reference_line])
fig.update_layout(title='Interactive ROC Curve',
                  xaxis_title='False Positive Rate',
                  yaxis_title='True Positive Rate')
fig.show()

# %% [markdown]
# **Кросс-валидация**

# %% [markdown]
# Оценим модель с найденными гиперпараметрами в случае однократного применения, при 5-кратной кросс-валидации, при 10-кратной кросс-валидации. За основу возьмем значение AUC (ROC).

# %%
# Однократная оценка на тестовых данных
single_score = metrics.roc_auc_score(y_test, y_pred_proba2)
print("Однократная оценка эффективности (accuracy):", single_score)

# 5-кратная кросс-валидация на всем датасете
cross_val_scores = cross_val_score(model2, X, y, cv=5, scoring='roc_auc')
print("Среднее значение accuracy по 5-кратной кросс-валидации:", cross_val_scores.mean())

scores_10 = cross_val_score(model2, X, y, cv=10, scoring='roc_auc')
print("Среднее значение accuracy при 10-кратной кросс-валидации:", scores_10.mean())
# Out:
# Однократная оценка эффективности (accuracy): 0.8982456140350878
# Среднее значение accuracy по 5-кратной кросс-валидации: 0.9194962922770845
# Среднее значение accuracy при 10-кратной кросс-валидации: 0.9157732127938895

# %% [markdown]
# *При использовании кросс-валидации видим, что значение метрики (площадь под кривой ROC) не снижается, и немного растет, что свидетельствует о стабильности построенной нами модели и отсуствии переобучения при первичном построении.*

# %% [markdown]
# **Применим Recursive Feature Elimination (RFE) для выбора количества признаков**

# %%
from sklearn.feature_selection import RFE

n_features = list(range(2, len(df.columns)-1))
metrics = []

model3 = RandomForestClassifier(random_state=42)

for k in n_features:
  rfe = RFE(model3, n_features_to_select=k)
  rfe = rfe.fit(X_train, y_train)
  X_train_rfe = rfe.transform(X_train)
  X_test_rfe = rfe.transform(X_test)
  model3.fit(X_train_rfe, y_train)
  y_pred3 = model3.predict(X_test_rfe)
  f1 = f1_score(y_test, y_pred3, average = 'binary')
  metrics.append(f1)



plt.plot(n_features, metrics, marker = 's')
plt.title('Зависимость F1 меры от количества признаков')
plt.xlabel('Количество признаков')
plt.ylabel('F1');
plt.show()

# %% [markdown]
# Видим, что оптимальным является 13 признаков в модели, достаточным - 9. После этого метрика растет незначительно

# %%
model4 = RandomForestClassifier(random_state=42)
rfe = RFE(model4, n_features_to_select=9)
rfe = rfe.fit(X_train, y_train)

# %%
# Показываем какие признаки выбраны
selected_features = pd.DataFrame({
    'Feature': X.columns,  # Здесь X.columns должен содержать названия столбцов, использованных для X
    'Ranking': rfe.ranking_
})
print(selected_features.sort_values(by='Ranking', ascending=False))
# Out:
#                    Feature  Ranking
# 1                Area code       10
# 3          Voice mail plan        9
# 9          Total eve calls        8
# 12       Total night calls        7
# 0           Account length        6
# 11     Total night minutes        5
# 16       Total intl charge        4
# 6          Total day calls        3
# 13      Total night charge        2
# 5        Total day minutes        1
# 7         Total day charge        1
# 8        Total eve minutes        1
# 4    Number vmail messages        1
# 10        Total eve charge        1
# 2       International plan        1
# 14      Total intl minutes        1
# 15        Total intl calls        1
# 17  Customer service calls        1

# %%
X_train_rfe = rfe.transform(X_train)
X_test_rfe = rfe.transform(X_test)
model4.fit(X_train_rfe, y_train)
y_pred4 = model4.predict(X_test_rfe)
print(classification_report(y_test, y_pred4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       855
#            1       0.90      0.74      0.81       145
#
#     accuracy                           0.95      1000
#    macro avg       0.93      0.86      0.89      1000
# weighted avg       0.95      0.95      0.95      1000

# %%
confusion_mat = confusion_matrix(y_test, y_pred4)
print("Точность:", accuracy_score(y_test, y_pred4))
print("Точность:", precision_score(y_test, y_pred4, average = 'binary'))
print("Полнота:", recall_score(y_test, y_pred4, average = 'binary'))
print("F1-мера:", f1_score(y_test, y_pred4, average = 'binary'))
# Out:
# Точность: 0.95
# Точность: 0.8991596638655462
# Полнота: 0.7379310344827587
# F1-мера: 0.8106060606060606

# %%
sns.heatmap(confusion_mat, annot=True, fmt="d", cmap = "Blues")
plt.xlabel("Прогноз")
plt.ylabel("Фактическое значение")
plt.title("Матрица ошибок")
plt.show();

# %% [markdown]
# *Видим, что при таком количестве признаков качество модели практически не ухудшилось*

# %% [markdown]
# **В настоящей работе мы применили классификацию с помощью модели RandomForestClassifier "из коробки", попробовали улучшить метрики качества при помощи подбора гиперпараметров GridSearchCV - убедились, что в случае с RandomForestClassifier модель дает хорошие метрики даже с параметрами по умолчанию. С помощью кросс-валидации убедились в том, что модель не склонна к переобучению. С применением Recursive Feature Elimination нашли, что для модели достаточно оставить 9 из 17 признаков - качество модели от этого практически не ухудшается**.
