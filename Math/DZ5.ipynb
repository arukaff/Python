# %% [markdown]
# 1. Когда используется критерий Стьюдента, а когда Z –критерий?
#
# Ответ: Z критерий используется когда извесно стандартное несмещенное  отклонение (сигма) генеральной совокупности

# %% [markdown]
# 2. Проведите тест гипотезы.
#
# Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм. Используя односторонний критерий с α=0,05, проверить эту гипотезу, если в выборке из n=100 шариков средний диаметр оказался равным 17.5 мм, а дисперсия известна и равна 4 кв. мм.

# %%
Zt=1.645
Zn=(17.5-17)/(4/(100**(1/2)))
print(f'Гипотеза верна, так как при 𝛼=0.05 Z табличное равно 1.645, что больше Z выборки равное {Zn} ')
# Out:
# Гипотеза верна, так как при 𝛼=0.05 Z табличное равно 1.645, что больше Z выборки равное 1.25

# %% [markdown]
# 3. Проведите тест гипотезы.
#
# Продавец утверждает, что средний вес пачки печенья составляет 200 г. Из партии извлечена выборка из 10 пачек. Вес каждой пачки составляет: 202, 203, 199, 197, 195, 201, 200, 204, 194, 190. Известно, что их веса распределены нормально. Верно ли утверждение продавца, если учитывать, что доверительная вероятность равна 99%? (Провести двусторонний тест.)

# %%
import numpy as np
arr=np.array([202, 203, 199, 197, 195, 201, 200, 204, 194, 190])
print(f'Среднее выборочное: {np.mean(arr): .2f},\n'
      f'Размер выборки n={len(arr)},\n'
      f'Среднее квадратическое отклонение по выборке(несмещенное): {np.std(arr, ddof=1): .2f}.'
     )
tn=(198.5-200)/(4.45/(10)**0.5) # Поскольку нам не известны ни среднее, ни дисперсия генеральной совокупности, то для проверки гипотезы будем использовать t-критерий
print(f'Гипотеза верна, так как при 𝛼=0.005 (двусторонний тест 𝛼=(1-0,99)/2) t табличное равно 3.2498, что больше t выборки равное {np.abs(tn): .4f} ')
# Out:
# Среднее выборочное:  198.50,
# Размер выборки n=10,
# Среднее квадратическое отклонение по выборке(несмещенное):  4.45.
# Гипотеза верна, так как при 𝛼=0.005 (двусторонний тест 𝛼=(1-0,99)/2) t табличное равно 3.2498, что больше t выборки равное  1.0659

# %% [markdown]
# 4. Есть ли статистически значимые различия в росте дочерей?
#
# Рост матерей 172, 177, 158, 170, 178,175, 164, 160, 169, 165
#
# Рост взрослых дочерей: 173, 175, 162, 174, 175, 168, 155, 170, 160

# %%
from scipy import stats 
m=np.array([172, 177, 158, 170, 178, 175, 164, 160, 169, 165])
d=np.array([173, 175, 162, 174, 175, 168, 155, 170, 160, 165])
stats.ttest_rel(m, d) 
print('pvalue=0.5879, что занчительно больше самого высокого уровня статистической значимости в 10%, а значит статистически значимых различий нет')
# Out:
# TtestResult(statistic=np.float64(0.561910752543762), pvalue=np.float64(0.5878952838568936), df=np.int64(9))
